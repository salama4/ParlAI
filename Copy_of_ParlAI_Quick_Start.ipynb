# %% [markdown]
# <a href="https://colab.research.google.com/github/salama4/ParlAI/blob/master/Copy_of_ParlAI_Quick_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🦜 Welcome to the ParlAI Quick-Start Guide!

# %% [markdown]
# <img width="200" src='https://parl.ai/static/img/icon.png' />
#
# In this guide, you will:
#
# - Get a basic overview of the ParlAI ecosystem
# - Train your first dialogue model
# - Evaluate your dialogue model

# %% [markdown]
# # [Prerequisite] Installation & Setup
#
# First, we'll download the latest copy of the ParlAI codebase located at https://github.com/facebookresearch/ParlAI and install.

# %%
# %%capture installation_output

# !git clone --depth 1 https://github.com/facebookresearch/ParlAI.git ~/ParlAI
# %cd ~/ParlAI
# !python setup.py develop

# %%
# If you think an error may have occured during installation,
# uncomment & run the below to inspect the output:

# installation_output.show()

# %% [markdown]
# # Working with Datasets
#
# The ParlAI repository contains many dialogue "tasks" which can be thought of as specialized datasets. The full list of tasks can be found [here](https://github.com/facebookresearch/ParlAI/tree/master/parlai/tasks/task_list.py).
#
#
# There exists a handy utility script at  `examples/display_data.py` which helps you to view data from the myriad tasks contained in the ParlAI repository.
#
#
# 💡**TIP**: The first-time you reference a task, ParlAI will automatically download the data for you under-the-hood! (The data files are stored in the `data` subdirectory wherever you installed ParlAI)
#
# ---
#
# Let's use `display_data.py` to see data from the [bAbI dataset](https://research.fb.com/downloads/babi/):

# %%
#@title Viewing the bAbI dataset
# !python examples/display_data.py -t babi:task1k:1,squad -n 100
# Out:
# [ optional arguments: ]
# [  display_ignore_fields: agent_reply ]
# [  max_display_len: 1000 ]
# [  num_examples: 100 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: train:stream ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task1k:1,squad ]
# [ ParlAI Model Arguments: ]
# [  dict_class: None ]
# [  init_model: None ]
# [  model: None ]
# [  model_file: None ]
# [ PytorchData Arguments: ]
# [  batch_length_range: 5 ]
# [  batch_sort_cache_type: pop ]
# [  batch_sort_field: text ]
# [  numworkers: 4 ]
# [  pytorch_context_length: -1 ]
# [  pytorch_datapath: None ]
# [  pytorch_include_labels: True ]
# [  pytorch_preprocess: False ]
# [  pytorch_teacher_batch_sort: False ]
# [  pytorch_teacher_dataset: None ]
# [  pytorch_teacher_task: None ]
# [  shuffle: False ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Current ParlAI commit: 7c294d523428fa29f8cb9824664752022f534cd7 ]
# [creating task(s): babi:task1k:1,squad]
# [building data: /root/ParlAI/data/bAbI]
# [ downloading: http://parl.ai/downloads/babi/babi.tar.gz to /root/ParlAI/data/bAbI/babi.tar.gz ]
# Downloading babi.tar.gz: 100% 19.2M/19.2M [00:00<00:00, 20.4MB/s]
# unpacking babi.tar.gz
# [building data: /root/ParlAI/data/SQuAD]
# [ downloading: https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json to /root/ParlAI/data/SQuAD/train-v1.1.json ]
# Downloading train-v1.1.json: 100% 30.3M/30.3M [00:01<00:00, 18.1MB/s]
# [ downloading: https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json to /root/ParlAI/data/SQuAD/dev-v1.1.json ]
# Downloading dev-v1.1.json: 100% 4.85M/4.85M [00:00<00:00, 17.9MB/s]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/qa1_train.txt]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/qa1_train.txt]
# loading: /root/ParlAI/data/SQuAD/train-v1.1.json
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary moved to the bathroom.
# John went to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Daniel went back to the hallway.
# Sandra moved to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: John moved to the office.
# Sandra journeyed to the bathroom.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Mary moved to the hallway.
# Daniel travelled to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: John went back to the garden.
# John moved to the bedroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# loading: /root/ParlAI/data/SQuAD/train-v1.1.json
# [world 1:squad]
# [squad]: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# [labels: Saint Bernadette Soubirous]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: John went to the garden.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: John went to the bedroom.
# John travelled to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# What is in front of the Notre Dame Main Building?
# [labels: a copper statue of Christ]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary went to the bedroom.
# John journeyed to the bathroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra journeyed to the hallway.
# John journeyed to the garden.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: John journeyed to the bathroom.
# Sandra journeyed to the garden.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra went back to the bedroom.
# Daniel travelled to the bathroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: John went to the office.
# Mary moved to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# [labels: the Main Building]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary moved to the garden.
# John journeyed to the bathroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra moved to the office.
# John moved to the kitchen.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: Sandra went to the hallway.
# Mary travelled to the bedroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Mary moved to the office.
# John moved to the garden.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: John journeyed to the office.
# Sandra went to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# What is the Grotto at Notre Dame?
# [labels: a Marian place of prayer and reflection]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary moved to the garden.
# Daniel journeyed to the bathroom.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: John travelled to the kitchen.
# John went back to the bedroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: John moved to the office.
# Daniel went back to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: John went back to the hallway.
# Mary went to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Sandra travelled to the bedroom.
# John travelled to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# What sits on top of the Main Building at Notre Dame?
# [labels: a golden statue of the Virgin Mary]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: John moved to the bedroom.
# Mary moved to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Sandra moved to the bedroom.
# Sandra travelled to the kitchen.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Daniel journeyed to the bathroom.
# Sandra moved to the bathroom.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Daniel went back to the garden.
# John moved to the kitchen.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Daniel journeyed to the kitchen.
# Daniel journeyed to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an ...
# to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
# When did the Scholastic Magazine of Notre dame begin publishing?
# [labels: September 1876]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary went to the kitchen.
# John went back to the bedroom.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Mary went back to the bathroom.
# Mary moved to the hallway.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: John went to the kitchen.
# Daniel travelled to the bedroom.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: Mary travelled to the office.
# Sandra moved to the bedroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: John moved to the bedroom.
# Sandra journeyed to the kitchen.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an ...
# are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
# How often is Notre Dame's the Juggler published?
# [labels: twice]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Daniel moved to the hallway.
# Daniel travelled to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Daniel went to the bedroom.
# Daniel journeyed to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra went back to the bathroom.
# Sandra journeyed to the kitchen.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Daniel moved to the bedroom.
# Daniel journeyed to the hallway.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Sandra travelled to the garden.
# Sandra went back to the bathroom.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an ...
# distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
# What is the daily student paper at Notre Dame called?
# [labels: The Observer]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra went to the garden.
# Sandra journeyed to the bedroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: Mary travelled to the bathroom.
# John journeyed to the bedroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: Mary went back to the kitchen.
# John went to the kitchen.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Daniel travelled to the kitchen.
# Sandra travelled to the bathroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra went back to the garden.
# John went back to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an ...
# distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
# How many student news papers are found at Notre Dame?
# [labels: three]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Mary went to the office.
# Sandra went to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an ...
# Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
# In what year did the student paper Common Sense begin publication at Notre Dame?
# [labels: 1987]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary went back to the office.
# John went back to the bathroom.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: John went to the hallway.
# Mary journeyed to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Sandra travelled to the hallway.
# Mary travelled to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Mary went back to the hallway.
# Sandra travelled to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: John went to the kitchen.
# Sandra went to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
# Where is the headquarters of the Congregation of the Holy Cross?
# [labels: Rome]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra moved to the hallway.
# John moved to the hallway.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: John journeyed to the bathroom.
# Daniel went back to the bedroom.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Mary travelled to the bedroom.
# Mary journeyed to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: John travelled to the bedroom.
# Sandra journeyed to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: John journeyed to the kitchen.
# Sandra went to the kitchen.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
# What is the primary seminary of the Congregation of the Holy Cross?
# [labels: Moreau Seminary]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Daniel went to the kitchen.
# Mary travelled to the hallway.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Daniel went back to the garden.
# Mary went back to the bathroom.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra moved to the hallway.
# John moved to the garden.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: Daniel moved to the kitchen.
# Mary travelled to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Daniel travelled to the hallway.
# Sandra travelled to the bathroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
# What is the oldest structure at Notre Dame?
# [labels: Old College]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra moved to the kitchen.
# Sandra went back to the garden.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: Sandra journeyed to the office.
# Mary moved to the office.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra journeyed to the bathroom.
# Daniel moved to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Daniel went back to the kitchen.
# Mary moved to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: John went to the office.
# Sandra went to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
# What individuals live at Fatima House at Notre Dame?
# [labels: Retired priests and brothers]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Sandra went to the garden.
# Mary travelled to the bathroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: garden]
# ~~
# [babi:task1k:1]: Sandra moved to the bathroom.
# Mary travelled to the hallway.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Mary went back to the kitchen.
# Daniel travelled to the bedroom.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# ~~
# [babi:task1k:1]: Mary journeyed to the bedroom.
# Mary journeyed to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task1k:1]: Mary went back to the bedroom.
# Daniel went to the garden.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bedroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
# Which prize did Frederick Buechner create?
# [labels: Buechner Prize for Preaching]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary journeyed to the garden.
# Sandra went back to the office.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra went to the bathroom.
# John travelled to the bathroom.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Sandra moved to the bedroom.
# Sandra travelled to the hallway.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task1k:1]: Mary moved to the bathroom.
# John went to the kitchen.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task1k:1]: Daniel moved to the bathroom.
# Daniel went to the office.
# Where is John?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: kitchen]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 1:squad]
# [squad]: The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively.
# How many BS level degrees are offered in the College of Engineering at Notre Dame?
# [labels: eight]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [world 0:babi:task1k:1]
# [babi:task1k:1]: Mary moved to the office.
# Daniel went to the kitchen.
# Where is Mary?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra went to the bathroom.
# Daniel moved to the office.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Sandra went to the office.
# Sandra went to the hallway.
# Where is Daniel?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: office]
# ~~
# [babi:task1k:1]: Mary went to the garden.
# Daniel moved to the kitchen.
# Where is Sandra?
# [label_candidates: kitchen|hallway|garden|office|bedroom|...and 1 more]
# [labels: hallway]
# ~~
# [ loaded 87779 episodes with a total of 88499 examples ]

# %% [markdown]
# # Training and Evaluating Models

# %%
#@title Training a model on the dataset
# !python examples/train_model.py -t babi:task10k:1 -m memnn -mf /tmp/babi_memnn -bs 1 -nt 4 -eps 5 --no-cuda
# Out:
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: train ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 4 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: memnn ]
# [  model_file: /tmp/babi_memnn ]
# [ Training Loop Arguments: ]
# [  aggregate_micro: False ]
# [  dict_build_first: True ]
# [  display_examples: False ]
# [  eval_batchsize: None ]
# [  evaltask: None ]
# [  load_from_checkpoint: False ]
# [  max_train_time: -1 ]
# [  metrics: default ]
# [  num_epochs: 5.0 ]
# [  save_after_valid: False ]
# [  save_every_n_secs: -1 ]
# [  short_final_eval: False ]
# [  validation_cutoff: 1.0 ]
# [  validation_every_n_epochs: -1 ]
# [  validation_every_n_secs: -1 ]
# [  validation_max_exs: -1 ]
# [  validation_metric: accuracy ]
# [  validation_metric_mode: None ]
# [  validation_patience: 10 ]
# [  validation_share_agent: False ]
# [ Tensorboard Arguments: ]
# [  tensorboard_log: False ]
# [ PytorchData Arguments: ]
# [  batch_length_range: 5 ]
# [  batch_sort_cache_type: pop ]
# [  batch_sort_field: text ]
# [  numworkers: 4 ]
# [  pytorch_context_length: -1 ]
# [  pytorch_datapath: None ]
# [  pytorch_include_labels: True ]
# [  pytorch_preprocess: False ]
# [  pytorch_teacher_batch_sort: False ]
# [  pytorch_teacher_dataset: None ]
# [  pytorch_teacher_task: None ]
# [  shuffle: False ]
# [ Dictionary Loop Arguments: ]
# [  dict_include_test: False ]
# [  dict_include_valid: False ]
# [  dict_maxexs: -1 ]
# [  log_every_n_secs: 2 ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ MemNN Arguments: ]
# [  embedding_size: 128 ]
# [  hops: 3 ]
# [  memsize: 32 ]
# [  position_encoding: False ]
# [  time_features: True ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: True ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: random ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: False ]
# [  label_truncate: None ]
# [  no_cuda: True ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: True ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: (0.9, 0.999) ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 1 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: (0.7,) ]
# [  optimizer: sgd ]
# [  weight_decay: None ]
# [ Learning Rate Scheduler: ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ TorchRankerAgent: ]
# [  candidates: inline ]
# [  cap_num_predictions: 100 ]
# [  encode_candidate_vecs: True ]
# [  eval_candidates: inline ]
# [  fixed_candidate_vecs: reuse ]
# [  fixed_candidates_path: None ]
# [  ignore_bad_candidates: False ]
# [  init_model: None ]
# [  rank_top_k: -1 ]
# [  repeat_blocking_heuristic: True ]
# [  train_predict: False ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: None ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Current ParlAI commit: 7c294d523428fa29f8cb9824664752022f534cd7 ]
# [ building dictionary first... ]
# [creating task(s): babi:task10k:1]
# [ running dictionary over data.. ]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# Building dictionary:   0% 0.00/9.00k [00:00<?, ?ex/s][loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# Building dictionary:  82% 7.39k/9.00k [00:00<00:00, 24.7kex/s][loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# Building dictionary: 100% 9.00k/9.00k [00:00<00:00, 24.6kex/s]
# Dictionary: saving dictionary to /tmp/babi_memnn.dict
# [ dictionary built with 26 tokens in 0s ]
# [ no model with opt yet at: /tmp/babi_memnn(.opt) ]
# Dictionary: loading dictionary from /tmp/babi_memnn.dict
# [ num words =  26 ]
# [Memnn: full interactive mode on.]
# Total parameters: 46080
# Trainable parameters:  46080
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# [ 4 threads initialized ]
# [ training... ]
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:378: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:378: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:378: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:378: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# [ time:2.0s total_exs:427 epochs:0.05 time_left:209.0s ] {'exs': 427, 'lr': 1, 'num_updates': 0, 'gnorm': 67.78, 'clip': 0.99, 'examples': 424, 'loss': 2060.0, 'mean_loss': 4.858, 'mean_rank': 0, 'mrr': 0}
# [ time:4.0s total_exs:1070 epochs:0.12 time_left:165.0s ] {'exs': 643, 'lr': 1, 'num_updates': 0, 'gnorm': 46.37, 'clip': 0.89, 'examples': 639, 'loss': 1855.0, 'mean_loss': 2.903, 'mean_rank': 0, 'mrr': 0}
# [ time:6.0s total_exs:1728 epochs:0.19 time_left:151.0s ] {'exs': 658, 'lr': 1, 'num_updates': 0, 'gnorm': 31.92, 'clip': 0.53, 'examples': 648, 'loss': 700.7, 'mean_loss': 1.081, 'mean_rank': 0, 'mrr': 0}
# [ time:8.0s total_exs:2379 epochs:0.26 time_left:144.0s ] {'exs': 651, 'lr': 1, 'num_updates': 0, 'gnorm': 16.54, 'clip': 0.29, 'examples': 649, 'loss': 343.6, 'mean_loss': 0.5295, 'mean_rank': 0, 'mrr': 0}
# [ time:10.0s total_exs:3025 epochs:0.34 time_left:139.0s ] {'exs': 646, 'lr': 1, 'num_updates': 0, 'gnorm': 15.6, 'clip': 0.23, 'examples': 641, 'loss': 282.5, 'mean_loss': 0.4408, 'mean_rank': 0, 'mrr': 0}
# [ time:12.0s total_exs:3696 epochs:0.41 time_left:135.0s ] {'exs': 671, 'lr': 1, 'num_updates': 0, 'gnorm': 10.51, 'clip': 0.17, 'examples': 663, 'loss': 140.9, 'mean_loss': 0.2125, 'mean_rank': 0, 'mrr': 0}
# [ time:14.0s total_exs:4357 epochs:0.48 time_left:131.0s ] {'exs': 661, 'lr': 1, 'num_updates': 0, 'gnorm': 11.13, 'clip': 0.18, 'examples': 659, 'loss': 192.5, 'mean_loss': 0.2922, 'mean_rank': 0, 'mrr': 0}
# [ time:16.0s total_exs:5029 epochs:0.56 time_left:128.0s ] {'exs': 672, 'lr': 1, 'num_updates': 0, 'gnorm': 9.502, 'clip': 0.12, 'examples': 668, 'loss': 131.0, 'mean_loss': 0.1962, 'mean_rank': 0, 'mrr': 0}
# [ time:18.0s total_exs:5698 epochs:0.63 time_left:125.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 8.213, 'clip': 0.13, 'examples': 667, 'loss': 97.16, 'mean_loss': 0.1457, 'mean_rank': 0, 'mrr': 0}
# [ time:20.0s total_exs:6370 epochs:0.71 time_left:122.0s ] {'exs': 672, 'lr': 1, 'num_updates': 0, 'gnorm': 8.389, 'clip': 0.1, 'examples': 668, 'loss': 111.9, 'mean_loss': 0.1675, 'mean_rank': 0, 'mrr': 0}
# [ time:22.0s total_exs:7045 epochs:0.78 time_left:119.0s ] {'exs': 675, 'lr': 1, 'num_updates': 0, 'gnorm': 6.083, 'clip': 0.089, 'examples': 671, 'loss': 58.51, 'mean_loss': 0.0872, 'mean_rank': 0, 'mrr': 0}
# [ time:24.0s total_exs:7719 epochs:0.86 time_left:117.0s ] {'exs': 674, 'lr': 1, 'num_updates': 0, 'gnorm': 6.801, 'clip': 0.08, 'examples': 672, 'loss': 98.66, 'mean_loss': 0.1468, 'mean_rank': 0, 'mrr': 0}
# [ time:26.0s total_exs:8379 epochs:0.93 time_left:114.0s ] {'exs': 660, 'lr': 1, 'num_updates': 0, 'gnorm': 2.511, 'clip': 0.055, 'examples': 660, 'loss': 26.94, 'mean_loss': 0.04082, 'mean_rank': 0, 'mrr': 0}
# [ time:28.0s total_exs:9050 epochs:1.01 time_left:112.0s ] {'exs': 670, 'lr': 1, 'num_updates': 0, 'gnorm': 6.254, 'clip': 0.077, 'examples': 664, 'loss': 58.69, 'mean_loss': 0.08838, 'mean_rank': 0, 'mrr': 0}
# [ time:30.0s total_exs:9710 epochs:1.08 time_left:110.0s ] {'exs': 660, 'lr': 1, 'num_updates': 0, 'gnorm': 4.357, 'clip': 0.07, 'examples': 657, 'loss': 72.94, 'mean_loss': 0.111, 'mean_rank': 0, 'mrr': 0}
# [ time:32.0s total_exs:10385 epochs:1.15 time_left:107.0s ] {'exs': 675, 'lr': 1, 'num_updates': 0, 'gnorm': 5.692, 'clip': 0.091, 'examples': 673, 'loss': 48.29, 'mean_loss': 0.07176, 'mean_rank': 0, 'mrr': 0}
# [ time:34.0s total_exs:11062 epochs:1.23 time_left:105.0s ] {'exs': 677, 'lr': 1, 'num_updates': 0, 'gnorm': 4.087, 'clip': 0.076, 'examples': 673, 'loss': 36.93, 'mean_loss': 0.05488, 'mean_rank': 0, 'mrr': 0}
# [ time:36.0s total_exs:11727 epochs:1.3 time_left:103.0s ] {'exs': 665, 'lr': 1, 'num_updates': 0, 'gnorm': 5.103, 'clip': 0.089, 'examples': 661, 'loss': 47.08, 'mean_loss': 0.07122, 'mean_rank': 0, 'mrr': 0}
# [ time:38.0s total_exs:12389 epochs:1.38 time_left:101.0s ] {'exs': 662, 'lr': 1, 'num_updates': 0, 'gnorm': 3.104, 'clip': 0.061, 'examples': 658, 'loss': 23.36, 'mean_loss': 0.0355, 'mean_rank': 0, 'mrr': 0}
# [ time:40.0s total_exs:13054 epochs:1.45 time_left:98.0s ] {'exs': 665, 'lr': 1, 'num_updates': 0, 'gnorm': 4.441, 'clip': 0.054, 'examples': 662, 'loss': 42.44, 'mean_loss': 0.06411, 'mean_rank': 0, 'mrr': 0}
# [ time:42.0s total_exs:13731 epochs:1.53 time_left:96.0s ] {'exs': 677, 'lr': 1, 'num_updates': 0, 'gnorm': 4.805, 'clip': 0.04, 'examples': 672, 'loss': 60.14, 'mean_loss': 0.0895, 'mean_rank': 0, 'mrr': 0}
# [ time:44.0s total_exs:14393 epochs:1.6 time_left:94.0s ] {'exs': 662, 'lr': 1, 'num_updates': 0, 'gnorm': 2.608, 'clip': 0.035, 'examples': 657, 'loss': 28.24, 'mean_loss': 0.04298, 'mean_rank': 0, 'mrr': 0}
# [ time:46.0s total_exs:15058 epochs:1.67 time_left:92.0s ] {'exs': 665, 'lr': 1, 'num_updates': 0, 'gnorm': 3.236, 'clip': 0.063, 'examples': 662, 'loss': 16.18, 'mean_loss': 0.02444, 'mean_rank': 0, 'mrr': 0}
# [ time:48.0s total_exs:15732 epochs:1.75 time_left:90.0s ] {'exs': 674, 'lr': 1, 'num_updates': 0, 'gnorm': 3.502, 'clip': 0.037, 'examples': 671, 'loss': 19.95, 'mean_loss': 0.02973, 'mean_rank': 0, 'mrr': 0}
# [ time:50.0s total_exs:16410 epochs:1.82 time_left:88.0s ] {'exs': 678, 'lr': 1, 'num_updates': 0, 'gnorm': 2.814, 'clip': 0.051, 'examples': 673, 'loss': 23.29, 'mean_loss': 0.0346, 'mean_rank': 0, 'mrr': 0}
# [ time:52.0s total_exs:17080 epochs:1.9 time_left:86.0s ] {'exs': 670, 'lr': 1, 'num_updates': 0, 'gnorm': 2.462, 'clip': 0.027, 'examples': 669, 'loss': 27.32, 'mean_loss': 0.04084, 'mean_rank': 0, 'mrr': 0}
# [ time:54.0s total_exs:17745 epochs:1.97 time_left:84.0s ] {'exs': 665, 'lr': 1, 'num_updates': 0, 'gnorm': 1.701, 'clip': 0.038, 'examples': 661, 'loss': 13.57, 'mean_loss': 0.02053, 'mean_rank': 0, 'mrr': 0}
# [ time:56.0s total_exs:18431 epochs:2.05 time_left:81.0s ] {'exs': 686, 'lr': 1, 'num_updates': 0, 'gnorm': 0.5894, 'clip': 0.015, 'examples': 675, 'loss': 11.12, 'mean_loss': 0.01647, 'mean_rank': 0, 'mrr': 0}
# [ time:58.0s total_exs:19111 epochs:2.12 time_left:79.0s ] {'exs': 680, 'lr': 1, 'num_updates': 0, 'gnorm': 0.6462, 'clip': 0.019, 'examples': 675, 'loss': 9.163, 'mean_loss': 0.01358, 'mean_rank': 0, 'mrr': 0}
# [ time:60.0s total_exs:19780 epochs:2.2 time_left:77.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 1.67, 'clip': 0.028, 'examples': 667, 'loss': 15.49, 'mean_loss': 0.02323, 'mean_rank': 0, 'mrr': 0}
# [ time:62.0s total_exs:20456 epochs:2.27 time_left:75.0s ] {'exs': 676, 'lr': 1, 'num_updates': 0, 'gnorm': 2.212, 'clip': 0.039, 'examples': 675, 'loss': 32.24, 'mean_loss': 0.04777, 'mean_rank': 0, 'mrr': 0}
# [ time:64.0s total_exs:21140 epochs:2.35 time_left:73.0s ] {'exs': 684, 'lr': 1, 'num_updates': 0, 'gnorm': 2.625, 'clip': 0.025, 'examples': 682, 'loss': 13.85, 'mean_loss': 0.02031, 'mean_rank': 0, 'mrr': 0}
# [ time:66.0s total_exs:21817 epochs:2.42 time_left:71.0s ] {'exs': 677, 'lr': 1, 'num_updates': 0, 'gnorm': 3.009, 'clip': 0.049, 'examples': 672, 'loss': 52.63, 'mean_loss': 0.07832, 'mean_rank': 0, 'mrr': 0}
# [ time:68.0s total_exs:22498 epochs:2.5 time_left:69.0s ] {'exs': 681, 'lr': 1, 'num_updates': 0, 'gnorm': 1.383, 'clip': 0.034, 'examples': 675, 'loss': 9.703, 'mean_loss': 0.01438, 'mean_rank': 0, 'mrr': 0}
# [ time:70.0s total_exs:23176 epochs:2.58 time_left:66.0s ] {'exs': 678, 'lr': 1, 'num_updates': 0, 'gnorm': 1.118, 'clip': 0.045, 'examples': 673, 'loss': 21.61, 'mean_loss': 0.03211, 'mean_rank': 0, 'mrr': 0}
# [ time:72.0s total_exs:23861 epochs:2.65 time_left:64.0s ] {'exs': 685, 'lr': 1, 'num_updates': 0, 'gnorm': 2.105, 'clip': 0.032, 'examples': 681, 'loss': 11.84, 'mean_loss': 0.01739, 'mean_rank': 0, 'mrr': 0}
# [ time:74.0s total_exs:24528 epochs:2.73 time_left:62.0s ] {'exs': 667, 'lr': 1, 'num_updates': 0, 'gnorm': 2.678, 'clip': 0.036, 'examples': 662, 'loss': 15.86, 'mean_loss': 0.02396, 'mean_rank': 0, 'mrr': 0}
# [ time:76.0s total_exs:25213 epochs:2.8 time_left:60.0s ] {'exs': 685, 'lr': 1, 'num_updates': 0, 'gnorm': 1.406, 'clip': 0.025, 'examples': 678, 'loss': 8.524, 'mean_loss': 0.01257, 'mean_rank': 0, 'mrr': 0}
# [ time:78.0s total_exs:25889 epochs:2.88 time_left:58.0s ] {'exs': 676, 'lr': 1, 'num_updates': 0, 'gnorm': 1.875, 'clip': 0.034, 'examples': 673, 'loss': 13.19, 'mean_loss': 0.01961, 'mean_rank': 0, 'mrr': 0}
# [ time:80.0s total_exs:26562 epochs:2.95 time_left:56.0s ] {'exs': 673, 'lr': 1, 'num_updates': 0, 'gnorm': 2.291, 'clip': 0.037, 'examples': 672, 'loss': 34.94, 'mean_loss': 0.052, 'mean_rank': 0, 'mrr': 0}
# [ time:82.0s total_exs:27236 epochs:3.03 time_left:54.0s ] {'exs': 674, 'lr': 1, 'num_updates': 0, 'gnorm': 0.7771, 'clip': 0.03, 'examples': 666, 'loss': 5.608, 'mean_loss': 0.008421, 'mean_rank': 0, 'mrr': 0}
# [ time:84.0s total_exs:27905 epochs:3.1 time_left:52.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 1.358, 'clip': 0.025, 'examples': 667, 'loss': 21.43, 'mean_loss': 0.03213, 'mean_rank': 0, 'mrr': 0}
# [ time:86.0s total_exs:28574 epochs:3.17 time_left:50.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 1.677, 'clip': 0.016, 'examples': 663, 'loss': 10.64, 'mean_loss': 0.01605, 'mean_rank': 0, 'mrr': 0}
# [ time:88.0s total_exs:29252 epochs:3.25 time_left:48.0s ] {'exs': 678, 'lr': 1, 'num_updates': 0, 'gnorm': 0.8984, 'clip': 0.021, 'examples': 676, 'loss': 11.4, 'mean_loss': 0.01686, 'mean_rank': 0, 'mrr': 0}
# [ time:90.0s total_exs:29925 epochs:3.33 time_left:46.0s ] {'exs': 673, 'lr': 1, 'num_updates': 0, 'gnorm': 1.419, 'clip': 0.03, 'examples': 672, 'loss': 7.64, 'mean_loss': 0.01137, 'mean_rank': 0, 'mrr': 0}
# [ time:92.0s total_exs:30594 epochs:3.4 time_left:44.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 1.899, 'clip': 0.03, 'examples': 667, 'loss': 9.679, 'mean_loss': 0.01451, 'mean_rank': 0, 'mrr': 0}
# [ time:94.0s total_exs:31262 epochs:3.47 time_left:42.0s ] {'exs': 668, 'lr': 1, 'num_updates': 0, 'gnorm': 1.036, 'clip': 0.018, 'examples': 666, 'loss': 4.63, 'mean_loss': 0.006951, 'mean_rank': 0, 'mrr': 0}
# [ time:96.0s total_exs:31934 epochs:3.55 time_left:40.0s ] {'exs': 672, 'lr': 1, 'num_updates': 0, 'gnorm': 0.8562, 'clip': 0.013, 'examples': 667, 'loss': 3.476, 'mean_loss': 0.005211, 'mean_rank': 0, 'mrr': 0}
# [ time:98.0s total_exs:32603 epochs:3.62 time_left:38.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 2.454, 'clip': 0.027, 'examples': 669, 'loss': 24.12, 'mean_loss': 0.03605, 'mean_rank': 0, 'mrr': 0}
# [ time:100.0s total_exs:33273 epochs:3.7 time_left:36.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 2.459, 'clip': 0.026, 'examples': 660, 'loss': 12.18, 'mean_loss': 0.01846, 'mean_rank': 0, 'mrr': 0}
# [ time:102.0s total_exs:33953 epochs:3.77 time_left:34.0s ] {'exs': 680, 'lr': 1, 'num_updates': 0, 'gnorm': 0.1075, 'clip': 0.012, 'examples': 675, 'loss': 0.201, 'mean_loss': 0.0002978, 'mean_rank': 0, 'mrr': 0}
# [ time:104.0s total_exs:34633 epochs:3.85 time_left:32.0s ] {'exs': 681, 'lr': 1, 'num_updates': 0, 'gnorm': 0.01435, 'clip': 0.0074, 'examples': 678, 'loss': 0.02663, 'mean_loss': 3.927e-05, 'mean_rank': 0, 'mrr': 0}
# [ time:106.0s total_exs:35310 epochs:3.92 time_left:30.0s ] {'exs': 676, 'lr': 1, 'num_updates': 0, 'gnorm': 0.003586, 'clip': 0.003, 'examples': 666, 'loss': 0.007697, 'mean_loss': 1.156e-05, 'mean_rank': 0, 'mrr': 0}
# [ time:108.0s total_exs:35989 epochs:4.0 time_left:28.0s ] {'exs': 679, 'lr': 1, 'num_updates': 0, 'gnorm': 1.189, 'clip': 0.019, 'examples': 675, 'loss': 11.42, 'mean_loss': 0.01692, 'mean_rank': 0, 'mrr': 0}
# [ time:110.0s total_exs:36672 epochs:4.07 time_left:26.0s ] {'exs': 683, 'lr': 1, 'num_updates': 0, 'gnorm': 0.3503, 'clip': 0.022, 'examples': 678, 'loss': 0.7119, 'mean_loss': 0.00105, 'mean_rank': 0, 'mrr': 0}
# [ time:112.0s total_exs:37340 epochs:4.15 time_left:24.0s ] {'exs': 668, 'lr': 1, 'num_updates': 0, 'gnorm': 0.2058, 'clip': 0.015, 'examples': 665, 'loss': 0.4601, 'mean_loss': 0.0006918, 'mean_rank': 0, 'mrr': 0}
# [ time:114.0s total_exs:38009 epochs:4.22 time_left:21.0s ] {'exs': 669, 'lr': 1, 'num_updates': 0, 'gnorm': 2.75, 'clip': 0.021, 'examples': 659, 'loss': 22.66, 'mean_loss': 0.03439, 'mean_rank': 0, 'mrr': 0}
# [ time:116.0s total_exs:38694 epochs:4.3 time_left:19.0s ] {'exs': 685, 'lr': 1, 'num_updates': 0, 'gnorm': 0.3567, 'clip': 0.0073, 'examples': 684, 'loss': 1.706, 'mean_loss': 0.002495, 'mean_rank': 0, 'mrr': 0}
# [ time:118.0s total_exs:39376 epochs:4.38 time_left:17.0s ] {'exs': 682, 'lr': 1, 'num_updates': 0, 'gnorm': 0.0001013, 'clip': 0, 'examples': 677, 'loss': 0.0002098, 'mean_loss': 3.099e-07, 'mean_rank': 0, 'mrr': 0}
# [ time:120.0s total_exs:40042 epochs:4.45 time_left:15.0s ] {'exs': 666, 'lr': 1, 'num_updates': 0, 'gnorm': 0.01193, 'clip': 0.006, 'examples': 659, 'loss': 0.02532, 'mean_loss': 3.842e-05, 'mean_rank': 0, 'mrr': 0}
# [ time:122.0s total_exs:40728 epochs:4.53 time_left:13.0s ] {'exs': 686, 'lr': 1, 'num_updates': 0, 'gnorm': 0.7971, 'clip': 0.02, 'examples': 683, 'loss': 8.03, 'mean_loss': 0.01176, 'mean_rank': 0, 'mrr': 0}
# [ time:124.0s total_exs:41400 epochs:4.6 time_left:11.0s ] {'exs': 672, 'lr': 1, 'num_updates': 0, 'gnorm': 0.6793, 'clip': 0.006, 'examples': 667, 'loss': 7.264, 'mean_loss': 0.01089, 'mean_rank': 0, 'mrr': 0}
# [ time:126.0s total_exs:42068 epochs:4.67 time_left:9.0s ] {'exs': 668, 'lr': 1, 'num_updates': 0, 'gnorm': 1.109, 'clip': 0.009, 'examples': 660, 'loss': 6.242, 'mean_loss': 0.009457, 'mean_rank': 0, 'mrr': 0}
# [ time:128.0s total_exs:42740 epochs:4.75 time_left:7.0s ] {'exs': 672, 'lr': 1, 'num_updates': 0, 'gnorm': 0.7129, 'clip': 0.0075, 'examples': 668, 'loss': 2.343, 'mean_loss': 0.003507, 'mean_rank': 0, 'mrr': 0}
# [ time:130.0s total_exs:43411 epochs:4.82 time_left:5.0s ] {'exs': 671, 'lr': 1, 'num_updates': 0, 'gnorm': 1.302, 'clip': 0.017, 'examples': 666, 'loss': 7.794, 'mean_loss': 0.0117, 'mean_rank': 0, 'mrr': 0}
# [ time:132.0s total_exs:44081 epochs:4.9 time_left:3.0s ] {'exs': 671, 'lr': 1, 'num_updates': 0, 'gnorm': 1.886, 'clip': 0.036, 'examples': 658, 'loss': 10.14, 'mean_loss': 0.01541, 'mean_rank': 0, 'mrr': 0}
# [ time:134.0s total_exs:44746 epochs:4.97 time_left:1.0s ] {'exs': 664, 'lr': 1, 'num_updates': 0, 'gnorm': 0.8827, 'clip': 0.012, 'examples': 660, 'loss': 2.29, 'mean_loss': 0.00347, 'mean_rank': 0, 'mrr': 0}
# [ time:134.0s total_exs:45000 epochs:5.0 time_left:0s ] {'exs': 254, 'lr': 1, 'num_updates': 0, 'gnorm': 0.086, 'clip': 0.016, 'examples': 252, 'loss': 0.06698, 'mean_loss': 0.0002658, 'mean_rank': 0, 'mrr': 0}
# [ num_epochs completed:5.0 time elapsed:134.92542505264282s ]
# Dictionary: saving dictionary to /tmp/babi_memnn.dict
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# [ 4 threads initialized ]
# [ running eval: valid ]
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# [ eval completed in 1.79s ]
# valid:{'exs': 1000, 'accuracy': 0.997, 'f1': 0.997, 'hits@1': 0.997, 'hits@5': 1.0, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 9.97e-10, 'lr': 1, 'num_updates': 0, 'examples': 953, 'loss': 10.7, 'mean_loss': 0.01123, 'mean_rank': 0.9906, 'mrr': 0.9921}
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_test.txt]
# [ 4 threads initialized ]
# [ running eval: test ]
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:600: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# [ eval completed in 1.61s ]
# test:{'exs': 1000, 'accuracy': 0.988, 'f1': 0.988, 'hits@1': 0.988, 'hits@5': 1.0, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 9.88e-10, 'lr': 1, 'num_updates': 0, 'examples': 964, 'loss': 43.15, 'mean_loss': 0.04476, 'mean_rank': 1.01, 'mrr': 0.9927}

# %%
#@title Evaluating model accuracy
# !python examples/display_model.py -t babi:task10k:1 -mf /tmp/babi_memnn -ecands vocab
# Out:
# [ optional arguments: ]
# [  display_ignore_fields:  ]
# [  num_examples: 10 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: valid ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  init_opt: None ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: None ]
# [  model_file: /tmp/babi_memnn ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ MemNN Arguments: ]
# [  embedding_size: 128 ]
# [  hops: 3 ]
# [  memsize: 32 ]
# [  position_encoding: False ]
# [  time_features: True ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: True ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: random ]
# [  fp16: False ]
# [  gpu: -1 ]
# [  history_size: -1 ]
# [  interactive_mode: False ]
# [  label_truncate: None ]
# [  no_cuda: False ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: True ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  use_reply: label ]
# [ Optimizer Arguments: ]
# [  adam_eps: 1e-08 ]
# [  betas: (0.9, 0.999) ]
# [  gradient_clip: 0.1 ]
# [  learningrate: 1 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  nus: (0.7,) ]
# [  optimizer: sgd ]
# [  weight_decay: None ]
# [ Learning Rate Scheduler: ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  update_freq: 1 ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ TorchRankerAgent: ]
# [  candidates: inline ]
# [  cap_num_predictions: 100 ]
# [  encode_candidate_vecs: True ]
# [  eval_candidates: vocab ]
# [  fixed_candidate_vecs: reuse ]
# [  fixed_candidates_path: None ]
# [  ignore_bad_candidates: False ]
# [  init_model: None ]
# [  rank_top_k: -1 ]
# [  repeat_blocking_heuristic: True ]
# [  train_predict: False ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: None ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ Current ParlAI commit: 7c294d523428fa29f8cb9824664752022f534cd7 ]
# [ warning: overriding opt['eval_candidates'] to vocab (previously: inline )]
# Dictionary: loading dictionary from /tmp/babi_memnn.dict
# [ num words =  58 ]
# [Memnn: full interactive mode on.]
# Total parameters: 46080
# Trainable parameters:  46080
# Loading existing model parameters from /tmp/babi_memnn
# [ Loaded fixed candidate set (n = 57) from vocabulary ]
# [ Encoding fixed candidates set from (1 batch(es) of up to 256) ]
# 100% 1/1 [00:00<00:00, 859.84it/s]
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# /root/ParlAI/parlai/core/torch_ranker_agent.py:680: UserWarning: [ Executing eval mode with tokens from vocabulary as candidates. ]
#   ''.format(mode)
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: bathroom]
#    [Memnn]: bathroom
#    [text_candidates: bathroom|__tf25__|__tf10__|__tf9__|Where|...and 52 more]
# ~~
# [babi:task10k:1]: Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: bathroom]
#    [Memnn]: bathroom
#    [text_candidates: bathroom|__tf25__|?|__tf4__|__tf9__|...and 52 more]
# ~~
# [babi:task10k:1]: John went to the garden.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: bathroom]
#    [Memnn]: bathroom
#    [text_candidates: bathroom|__tf25__|__tf10__|Where|?|...and 52 more]
# ~~
# [babi:task10k:1]: Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: office]
#    [Memnn]: office
#    [text_candidates: office|kitchen|__tf27__|__tf12__|__tf20__|...and 52 more]
# ~~
# [babi:task10k:1]: John went to the bedroom.
# John travelled to the office.
# Where is Daniel?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: hallway]
#    [Memnn]: hallway
#    [text_candidates: hallway|__tf4__|__tf7__|Sandra|the|...and 52 more]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: garden]
#    [Memnn]: garden
#    [text_candidates: garden|__tf27__|__tf4__|__tf10__|the|...and 52 more]
# ~~
# [babi:task10k:1]: Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: office]
#    [Memnn]: office
#    [text_candidates: office|Where|__tf6__|__tf4__|__tf12__|...and 52 more]
# ~~
# [babi:task10k:1]: John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: office]
#    [Memnn]: office
#    [text_candidates: office|Where|__tf6__|__tf4__|__tf29__|...and 52 more]
# ~~
# [babi:task10k:1]: Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: office]
#    [Memnn]: office
#    [text_candidates: office|__tf12__|__tf23__|Where|__tf27__|...and 52 more]
# ~~
# [babi:task10k:1]: Mary went to the office.
# Sandra went to the office.
# Where is John?
# [label_candidates: hallway|bathroom|office|kitchen|garden|...and 1 more]
# [eval_labels: office]
#    [Memnn]: office
#    [text_candidates: office|Where|__tf10__|__tf20__|__tf23__|...and 52 more]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
